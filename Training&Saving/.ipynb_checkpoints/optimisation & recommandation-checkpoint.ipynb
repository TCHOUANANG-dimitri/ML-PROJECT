# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
resources=pd.read_csv("../Datasets/Resources.csv")
teachers=pd.read_csv("../Datasets/teachers.csv")
courses=pd.read_csv("../Datasets/courses.csv")

# %%
resources
# Out:
#      Type_ressource Identifiant_ressource             Nom_matiere Filiere  \
# 0             Salle                 26BP2        Chimie Organique     GPR
# 1             Salle                 31BS2        Chimie Organique     GPR
# 2             Salle                 27BP2        Chimie Organique     GPR
# 3             Salle                 22BS1        Chimie Organique     GPR
# 4             Salle                 23BP2        Chimie Organique     GPR
# ...             ...                   ...                     ...     ...
# 8746          Salle                 26BS1  Structures Métalliques     GCI
# 8747          Salle                 18BS2  Structures Métalliques     GCI
# 8748          Salle                 25BP1  Structures Métalliques     GCI
# 8749           Labo              Labo-GCI  Structures Métalliques     GCI
# 8750           Labo              Labo-GCI  Structures Métalliques     GCI
#
#       Niveau Cursus Annee_academique        Date Heure_debut Heure_fin  \
# 0          5    ING        2020/2021  2020-09-19       07:30     11:30
# 1          5    ING        2020/2021  2020-11-21       12:30     16:30
# 2          5    ING        2020/2021  2020-11-19       12:30     16:30
# 3          5    ING        2020/2021  2020-11-02       07:30     11:30
# 4          5    ING        2020/2021  2020-11-09       12:30     16:30
# ...      ...    ...              ...         ...         ...       ...
# 8746       4    ING        2022/2023  2023-05-17       07:30     11:30
# 8747       4    ING        2022/2023  2023-02-17       07:30     11:30
# 8748       4    ING        2022/2023  2023-05-01       07:30     11:30
# 8749       4    ING        2022/2023  2023-03-23       07:30     11:30
# 8750       4    ING        2022/2023  2023-03-07       07:30     11:30
#
#      Type_cours Periode_annee  Nb_personnes  Capacite Enseignant_id  \
# 0            CM    Semestre 1            73       120  ENS-GPR-0004
# 1            CM    Semestre 1            73       120  ENS-GPR-0008
# 2            CM    Semestre 1            73       120  ENS-GPR-0011
# 3            TD    Semestre 1            36        60  ENS-GPR-0006
# 4            TD    Semestre 1            36        60  ENS-GPR-0005
# ...         ...           ...           ...       ...           ...
# 8746         CM    Semestre 2             7        60  ENS-GCI-0011
# 8747         TD    Semestre 2             3        60  ENS-GCI-0002
# 8748         TD    Semestre 2             3        60  ENS-GCI-0015
# 8749         TP    Semestre 2             2        35  ENS-GCI-0012
# 8750         TP    Semestre 2             2        35  ENS-GCI-0004
#
#      Videoprojecteur Chevauchement Etat_utilisation_ressource
# 0                OUI           NON               BIEN_UTILISE
# 1                OUI           NON               BIEN_UTILISE
# 2                OUI           NON               BIEN_UTILISE
# 3                OUI           NON               BIEN_UTILISE
# 4                NON           NON               BIEN_UTILISE
# ...              ...           ...                        ...
# 8746             NON           NON               SOUS_UTILISE
# 8747             NON           NON               BIEN_UTILISE
# 8748             NON           NON               BIEN_UTILISE
# 8749             NON           NON               BIEN_UTILISE
# 8750             NON           NON               BIEN_UTILISE
#
# [8751 rows x 18 columns]

# %%
# Construction de la target et Feature enginiering

besoin_projecteur=[]
for i in range(resources.shape[0]):
    if resources.loc[i,"Type_cours"]=="CM":
        besoin_projecteur.append("OUI")
    if  resources.loc[i,"Type_cours"] =="TD":
        if resources.loc[i,"Filiere"] in ['GIT', 'SDIA', 'GESI', 'EEAT', 'Météorologie']:
            besoin_projecteur.append("OUI")
        else:
            besoin_projecteur.append("NON")
    if resources.loc[i,"Type_cours"] =="TP":
        if resources.loc[i,"Filiere"] in ['GIT', 'SDIA', 'GESI']:
            besoin_projecteur.append("OUI")
        else:
            besoin_projecteur.append("NON")
            
resources["besoin_projecteur"]=besoin_projecteur

resources["taux_occupation"]=resources.loc[:,"Nb_personnes"]/resources.loc[:,"Capacite"]

adequation_equipement=[]
for i in range(resources.shape[0]):
    if (resources.loc[i,"Videoprojecteur"]=="OUI" and resources.loc[i,"besoin_projecteur"]=="OUI") or (resources.loc[i,"Videoprojecteur"]=="NON" and resources.loc[i,"besoin_projecteur"]=="NON"):
        adequation_equipement.append(1)
    if resources.loc[i,"Videoprojecteur"]=="OUI" and resources.loc[i,"besoin_projecteur"]=="NON":
        adequation_equipement.append(0.5)
    if resources.loc[i,"Videoprojecteur"]=="NON" and resources.loc[i,"besoin_projecteur"]=="OUI":
        adequation_equipement.append(0)

resources["adequation_equipement"]=adequation_equipement

adequation_salle=[]
for i in range(resources.shape[0]):
    type_cours = resources.loc[i, "Type_cours"]
    type_ressource = resources.loc[i, "Type_ressource"]

    if (
        (type_cours == "CM" and type_ressource == "Salle") or
        (type_cours == "TD" and type_ressource == "Salle") or
        (type_cours == "TP" and type_ressource == "Labo")
    ):
        adequation_salle.append(1)
    else:
        adequation_salle.append(0)

resources["adequation_salle"]=adequation_salle

score=resources.loc[:,"taux_occupation"]*0.4+resources.loc[:,"adequation_equipement"]*0.3+resources.loc[:,"adequation_salle"]*0.3

resources["Score"]=score

resources.drop(columns=["Chevauchement","Etat_utilisation_ressource"],inplace=True)

End_Type_ressource=[]
for i in resources.loc[:,"Type_ressource"]:
    if i=="Labo":
        End_Type_ressource.append(2)
    else:
        if i=="Salle":
            End_Type_ressource.append(1)
        else:
            End_Type_ressource.append(0)

resources["End_Type_ressource"]=End_Type_ressource

End_Type_cours=[]
for i in resources.loc[:,"Type_cours"]:
    if i=="CM":
        End_Type_cours.append(2)
    else:
        if i=="TD":
            End_Type_cours.append(1)
        else:
            End_Type_cours.append(0)

resources["End_Type_cours"]=End_Type_cours

End_Videoprojecteur=[]
for i in resources.loc[:,"Videoprojecteur"]:
    if i=="OUI":
        End_Videoprojecteur.append(1)
    else:
        End_Videoprojecteur.append(0)

End_besoin_projecteur=[]
for i in resources.loc[:,"besoin_projecteur"]:
    if i=="OUI":
        End_besoin_projecteur.append(1)
    else:
        End_besoin_projecteur.append(0)

resources["End_Videoprojecteur"]=End_Videoprojecteur
resources["End_besoin_projecteur"]=End_besoin_projecteur

# %%
resources
# Out:
#      Type_ressource Identifiant_ressource             Nom_matiere Filiere  \
# 0             Salle                 26BP2        Chimie Organique     GPR
# 1             Salle                 31BS2        Chimie Organique     GPR
# 2             Salle                 27BP2        Chimie Organique     GPR
# 3             Salle                 22BS1        Chimie Organique     GPR
# 4             Salle                 23BP2        Chimie Organique     GPR
# ...             ...                   ...                     ...     ...
# 8746          Salle                 26BS1  Structures Métalliques     GCI
# 8747          Salle                 18BS2  Structures Métalliques     GCI
# 8748          Salle                 25BP1  Structures Métalliques     GCI
# 8749           Labo              Labo-GCI  Structures Métalliques     GCI
# 8750           Labo              Labo-GCI  Structures Métalliques     GCI
#
#       Niveau Cursus Annee_academique        Date Heure_debut Heure_fin  ...  \
# 0          5    ING        2020/2021  2020-09-19       07:30     11:30  ...
# 1          5    ING        2020/2021  2020-11-21       12:30     16:30  ...
# 2          5    ING        2020/2021  2020-11-19       12:30     16:30  ...
# 3          5    ING        2020/2021  2020-11-02       07:30     11:30  ...
# 4          5    ING        2020/2021  2020-11-09       12:30     16:30  ...
# ...      ...    ...              ...         ...         ...       ...  ...
# 8746       4    ING        2022/2023  2023-05-17       07:30     11:30  ...
# 8747       4    ING        2022/2023  2023-02-17       07:30     11:30  ...
# 8748       4    ING        2022/2023  2023-05-01       07:30     11:30  ...
# 8749       4    ING        2022/2023  2023-03-23       07:30     11:30  ...
# 8750       4    ING        2022/2023  2023-03-07       07:30     11:30  ...
#
#      Videoprojecteur besoin_projecteur  taux_occupation  \
# 0                OUI               OUI         0.608333
# 1                OUI               OUI         0.608333
# 2                OUI               OUI         0.608333
# 3                OUI               NON         0.600000
# 4                NON               NON         0.600000
# ...              ...               ...              ...
# 8746             NON               OUI         0.116667
# 8747             NON               NON         0.050000
# 8748             NON               NON         0.050000
# 8749             NON               NON         0.057143
# 8750             NON               NON         0.057143
#
#       adequation_equipement adequation_salle     Score End_Type_ressource  \
# 0                       1.0                1  0.843333                  1
# 1                       1.0                1  0.843333                  1
# 2                       1.0                1  0.843333                  1
# 3                       0.5                1  0.690000                  1
# 4                       1.0                1  0.840000                  1
# ...                     ...              ...       ...                ...
# 8746                    0.0                1  0.346667                  1
# 8747                    1.0                1  0.620000                  1
# 8748                    1.0                1  0.620000                  1
# 8749                    1.0                1  0.622857                  2
# 8750                    1.0                1  0.622857                  2
#
#       End_Type_cours  End_Videoprojecteur  End_besoin_projecteur
# 0                  2                    1                      1
# 1                  2                    1                      1
# 2                  2                    1                      1
# 3                  1                    1                      0
# 4                  1                    0                      0
# ...              ...                  ...                    ...
# 8746               2                    0                      1
# 8747               1                    0                      0
# 8748               1                    0                      0
# 8749               0                    0                      0
# 8750               0                    0                      0
#
# [8751 rows x 25 columns]

# %%
resources.to_csv("resources_new.csv",index=False)

# %%
import sys
import os
sys.path.append("..Models/optimisation des ressources")

# %%
import Models
# Out:
# ['C:\\Users\\DIMITRI\\Desktop\\ML project\\Training&Saving',
#  'D:\\Anaconda\\python312.zip',
#  'D:\\Anaconda\\DLLs',
#  'D:\\Anaconda\\Lib',
#  'D:\\Anaconda',
#  '',
#  'D:\\Anaconda\\Lib\\site-packages',
#  'D:\\Anaconda\\Lib\\site-packages\\win32',
#  'D:\\Anaconda\\Lib\\site-packages\\win32\\lib',
#  'D:\\Anaconda\\Lib\\site-packages\\Pythonwin',
#  'D:\\Anaconda\\Lib\\site-packages\\setuptools\\_vendor',
#  'Desktop/ML project/Dataets',
#  '../Models',
#  '..Models/optimisation des ressources/',
#  '..Models/optimisation des ressources',
#  '..Models/optimisation des ressources']

# %%
X=resources.loc[:,["Nb_personnes","Capacite","End_Type_ressource","End_Type_cours","End_Videoprojecteur","End_besoin_projecteur"]]
y=resources.loc[:,"Score"]
indices = np.random.permutation(len(resources))
split = int(0.8 * len(resources))

train_idx = indices[:split]
test_idx  = indices[split:]

X_train = X.iloc[train_idx]
X_test  = X.iloc[test_idx]

y_train = y[train_idx]
y_test  = y[test_idx]

# %%
model1=RandomForestRegressor()
model2=decisionTreeRegressor()
model3=GradientBoostingRegressor()
model4=XGBoostRegressor()

# %%
model.fit(X_train.values,y_train.values)
model.score(X_train.values,y_train.values)
